# %%
import pandas as pd
import json
import config as cf
from tqdm import tqdm
import random
from pandas.io.json import json_normalize
from nltk.corpus import stopwords
from collections import Counter
# from collections import OrderedDict
from nltk import word_tokenize
import math
from odict import odict
import os

# %%
def log(x):
    try:
        return math.log(x)
    except ValueError:
        return 0

# %%
def notEnglish(s): 
    results = []
    for t in s:
        try:
            t.encode(encoding='utf-8').decode('ascii')
        except UnicodeDecodeError:
            results.append(True)
        else:
            results.append(False)
    return results

# %%
dataPath = cf.ROOT_PATH + cf.DATA_PATH
reviewPath = dataPath + 'review.json'
max_records = 1e5
df = pd.read_json(reviewPath, lines=True, chunksize=max_records)
reviews = pd.DataFrame() # Initialize the dataframe
print('next step')
i = 0
try:
   for df_chunk in tqdm(df):
       if i > 2:
            break
       reviews = pd.concat([reviews, df_chunk])
       print(i)
       i=i +1
except ValueError:
       print ('\nSome messages in the file cannot be parsed')

# %%
reviews = reviews.drop(reviews[notEnglish(reviews['text'])].index)

# %%
df = pd.read_json(dataPath + 'user.json', lines=True, chunksize=max_records)
users = pd.DataFrame() # Initialize the dataframe
print('next step')
i = 0
try:
   for df_chunk in tqdm(df):
       if i > 2:
            break
       users = pd.concat([users, df_chunk])
       print(i)
       i=i +1
except ValueError:
       print ('\nSome messages in the file cannot be parsed')

# %%
reviews = reviews.merge(users[['user_id', 'cool', 'useful', 'funny', 'fans', 'review_count']], left_on='user_id', right_on='user_id')

# %%
reviews['user_score'] = 0
reviews['user_score'] = ((reviews['useful_y'].apply(log) + reviews['funny_y'].apply(log) + reviews['cool_y'].apply(log) + reviews['fans'].apply(log))/reviews['review_count'])

# %%
reviews['review_score'] = 0
reviews['review_score'] = reviews['useful_x'].apply(log) + reviews['cool_x'].apply(log) + reviews['funny_x'].apply(log)

# %%
reviews = reviews.drop(reviews[(reviews['user_score'] == 0) & (reviews['review_score'] == 0)].index)

# %%
aspects = ['food', 'price', 'service', 'ambience', 'misc']
for aspect in aspects:
    reviews[aspect] = random.uniform(reviews['stars'], reviews['stars'] * 9/4 - 29/4) * (reviews['review_score'] + reviews['user_score'])

# %%
drop_cols = ['date', 'useful_x', 'funny_x', 'cool_x', 'useful_y', 'cool_y', 'funny_y', 'user_id', 'fans', 'review_count', 'user_score', 'review_score']
reviews = reviews.drop(drop_cols, 1)

# %%
states = ['AZ', 'NC', 'NV', 'IL', 'OH', 'PA', 'WI']
i = 0
for state in states:
        statePath = dataPath + 'business_consumer/' + state
        for subdir, _, files in tqdm(os.walk(statePath)):
            for file in files:
                if 'business-ids.json' not in file:
                    business = pd.read_json(os.path.join(statePath, file))
                    leftcols = ['business_id', 'text', 'food', 'price', 'service', 'ambience', 'misc']
                    business = business.merge(reviews[leftcols], left_on='business_id', right_on='business_id') 
                    business.to_json(dataPath + '%s_business.json' % state, orient= 'records')

# %%
s=set(stopwords.words('english'))
for state in states:
    stateBusiness = dataPath + '%s_business.json' % state
    business = pd.read_json(stateBusiness)
    business['text'] = [dict(Counter(list(filter(lambda w: not w in s and w.isalpha(),word_tokenize(txt.lower()))))) for txt in tqdm(business['text'])]
    business.to_json(dataPath + '%s_business.json' % state, orient= 'records')

# %%
dataPath = cf.ROOT_PATH + cf.DATA_PATH
file = dataPath + 'Tempe_business_processed.json'
business = pd.read_json(file)

# %%
commonCols = ['address', 'business_id', 'city', 'latitude', 'longitude', 'name', 'postal_code', 'review_count', 'stars_x', 'state']
dictCols = ['business_id', 'text', 'hours', 'categories', 'stars_y']
dropCols = ['attributes', 'is_open', 'text', 'hours', 'categories', 'stars_y']

# %%
sliced = business[dictCols]

# %%
dropped = business.drop(dropCols, 1)

# %%
text = sliced[['business_id', 'text', 'stars_y']]
sliced = sliced.drop('text', 1)

# %%
dropped = dropped.groupby(commonCols).sum()
dropped = dropped.reset_index()

# %%
goodText = text[text['stars_y'] >= 4.0]
badText = text[text['stars_y'] <= 2.0]

# %%
allId = text['business_id']
badId = badText['business_id']
goodId = goodText['business_id']
between = text[(text['stars_y'] < 4.0) & (text['stars_y'] > 2.0)]
beId = between['business_id']
dropIds = beId[~beId.isin(goodId.append(badId))]

# %%
dropped=dropped[~dropped['business_id'].isin(dropIds)]
text = text[~text['business_id'].isin(dropIds)]
sliced = sliced[~sliced['business_id'].isin(dropIds)]

# %%
# calculate stars
stars = text.groupby(['business_id', 'stars_y'])['stars_y'].size().unstack(fill_value=0)
stars = stars.reset_index()
stars[[1,2,3,4,5]] = stars[[1,2,3,4,5]].divide(stars.sum(1), 0) * 100

# %%
def counter(df):
    return dict(sum((Counter(dict(x)) for x in df['text']), Counter()))

# %%
def orderDict(x):
    d = odict(sorted(x.items(), key=lambda t: t[1], reverse=True))
    results = {}
    i = 0
    for key, value in d.items():
        if i > 19:
            break
        results[key] = value
        i += 1
    return results

# %%
goodText = goodText.groupby('business_id').apply(counter).reset_index()
badText = badText.groupby('business_id').apply(counter).reset_index()
goodText[0] = goodText[0].apply(orderDict)
badText[0] = badText[0].apply(orderDict)

# %%
sliced = sliced.groupby('business_id').last().reset_index()
sliced = sliced.drop('stars_y',1)

# %%
# put everything together
temp = pd.concat([sliced, goodText])
temp = temp.groupby('business_id').last().reset_index()
temp = temp.rename(index=str, columns={0: "good words"})
temp = pd.concat([temp, badText])
temp = temp.groupby('business_id').last().reset_index()
temp = temp.rename(index=str, columns={0: "bad words"})
temp = pd.concat([temp, stars]).groupby('business_id').last().reset_index()
temp = pd.concat([dropped, temp]).groupby('business_id').last().reset_index()

# %%
temp.to_json(dataPath + 'test.json', orient = 'records')

# %%
temp
# Out:
#                 business_id  \
# 0    -0Sgh0QlUKVsWosCWJzGqQ
# 1    -4g68Hwm892_KPUuW5g1_Q
# 2    -8QlV3b_9H4BAh6LgMIr1g
# 3    -Gy0BAMgRN4sGlY7theqxQ
# 4    -IZvuqxekWEvJqDw308daQ
# 5    -cBQKodqi77Q0vk-9iDvQA
# 6    -gcS8S7aiHTwYROMC5QP5A
# 7    -s_U95xEEmJu5GK-srqpUA
# 8    -tcJmqzfaeEnpFMAelB7bA
# 9    -wUKgQXAMC4H5hiBOgpT6g
# 10   -xIrVu_7prj_0GDl1tds1w
# 9                                1415 West Elliot Road     3.863981
# 10                    1101 West University Dr, Ste 101    38.596415
# 11                         20 E University Dr, Ste 191     1.133385
# 12                                     5500 S Mill Ave     0.824919
# 13                                   818 W Broadway Rd    24.303862
# 14                                     752 W Elliot Rd    99.315344
# 15          Arizona Mills Mall, 5000 Arizona Mills Cir    -6.290241
# 16                                 849 W University Dr   638.710995
# 17                                      605 S Mill Ave   -29.799143
# 18                           939 E Guadalupe Rd, Ste 1    14.182161
# 19                                     705 S Forest Rd    20.776531
# 20                        960 W University Dr, Ste 108   385.463177
# 21                                  1030 W Broadway Rd     0.259251
# 22                       920 E University Dr, Ste D101    62.703666
# 23                                     1043 E Lemon St   132.894019
# 24                                     4403 S Rural Rd    34.401781
# 25                                 1674 E Southern Ave    21.224278
# 26                             640 S Mill Ave, Ste 120     2.038695
# 27                                    5 E Southern Ave     3.624572
# 28                            825 W Baseline Rd, Ste 1    -6.111504
# 29                          922 E Apache Blvd, Ste 106    -2.570650
# ..                                                 ...          ...
# 584                              1401-1525 W Elliot Rd    -0.798238
# 585                                    6440 S Rural Rd     5.464796
# 586                                960 W University Dr  2937.915676
# 587                                 1212 E Apache Blvd    57.390695
# 588                                  8510 S Emerald Dr    42.737706
# 589                           805 W Baseline Rd, Ste 3    -1.431933
# 590                                 1805 E Baseline Rd    12.665834
# 591                                  911 E Broadway Rd    -0.138017
# 592                                    744 W Elliot Rd    30.032343
# 593                   2000 E Rio Salado Pkwy, Ste 1213     0.064724
# 594                           1717 S Rural Rd, Ste 102    80.651131
# 595                      1301 E University Dr, Ste 112    53.470420
# 596                                    515 W Warner Rd    -9.423069
# 597  777 College Ave, Ste 101, Arizona State Univer...     2.054080
# 598                                1801 East Guadalupe    15.307652
# 599                                2350 E Southern Ave   106.214384
# 600                                  818 W Broadway Rd     9.861026
# 601                   2000 E Rio Salado Pkwy, Ste 1151   343.490895
# 602                         521 S College Ave, Ste 110     0.104363
# 603                                 690 South Mill Ave    21.621519
# 604                                1734 E Southern Ave    39.417377
# 605                                 1872 E Apache Blvd   488.091362
# 606                         950 E Baseline Rd, Ste 101    53.096484
# 607                                  2900 S Diablo Way    -0.189059
# 608                                  788 E Baseline Rd   143.425849
# 609                                 1530 W Baseline Rd   177.893084
# 610                                 1219 W Baseline Rd    93.020147
# 611                         1835 E Elliot Rd, Ste C109   195.486292
# 612                                 1519 W Baseline Rd    21.623258
# 613                         219 E Baseline Rd, Ste H-2   168.965774
#
#                                              bad words  \
# 0    {'boyfriend': 1, 'always': 2, 'liked': 1, 'dom...
# 1    {'heard': 2, 'people': 2, 'really': 7, 'rave':...
# 2    {'place': 22, 'may': 1, 'night': 1, 'service':...
# 3    {'looked': 1, 'forward': 1, 'trying': 1, 'new'...
# 4    {'hard': 2, 'deep': 2, 'fry': 1, 'frozen': 1, ...
# 5    {'stop': 1, 'friends': 7, 'awesome': 1, 'pre':...
# 6    {'restaurant': 4, 'really': 3, 'nice': 2, 'lot...
# 7    {'probably': 3, 'got': 10, 'worst': 5, 'cook':...
# 8    {'main': 1, 'reasons': 1, 'order': 9, 'often':...
# 9    {'location': 3, 'needs': 1, 'little': 2, 'help...
# 10   {'slow': 2, 'bad': 2, 'much': 2, 'said': 2, 'y...
# 11   {'hearing': 1, 'commercial': 1, 'time': 1, 'ra...
# 12   {'excited': 1, 'saw': 1, 'chicken': 2, 'pho': ...
# 13   {'used': 2, 'go': 3, 'attending': 1, 'asu': 1,...
# 14   {'ok': 2, 'really': 5, 'wanted': 3, 'give': 3,...
# 15   {'awful': 1, 'management': 2, 'employees': 2, ...
# 16   {'honestly': 1, 'prefer': 1, 'food': 27, 'serv...
# 17   {'place': 42, 'smells': 4, 'sour': 1, 'grimy':...
# 18   {'really': 23, 'wanted': 4, 'chinese': 23, 'fo...
# 19   {'used': 3, 'mai': 3, 'island': 3, 'grill': 3,...
# 20   {'place': 24, 'quite': 1, 'underwhelming': 1, ...
# 21   {'mr': 1, 'burrito': 1, 'moved': 1, 'salsitas'...
# 22   {'get': 22, 'buckwheat': 1, 'noodles': 1, 'aut...
# 23   {'first': 3, 'tip': 2, 'whole': 3, 'groupon': ...
# 24   {'saturday': 1, 'morning': 1, 'wait': 4, 'minu...
# 25   {'slowest': 1, 'unmotivated': 1, 'crew': 1, 'h...
# 26   {'know': 4, 'incredibly': 1, 'inept': 1, 'gett...
# 27   {'place': 3, 'gets': 2, 'worse': 2, 'every': 1...
# 28   {'food': 14, 'tasted': 2, 'fine': 1, 'regular'...
# 29   {'place': 1, 'serious': 1, 'potential': 1, 'am...
# ..                                                 ...
# 584  {'visited': 1, 'location': 2, 'last': 1, 'satu...
# 585  {'always': 7, 'like': 18, 'location': 5, 'pret...
# 586  {'seriously': 3, 'hot': 7, 'pockets': 2, 'tast...
# 587  {'oh': 2, 'god': 2, 'effed': 2, 'reuben': 1, '...
# 588  {'times': 6, 'typically': 1, 'good': 15, 'expe...
# 589  {'bread': 1, 'crummy': 1, 'half': 1, 'baked': ...
# 590  {'amazed': 1, 'place': 4, 'still': 1, 'busines...
# 591  {'came': 1, 'get': 1, 'food': 1, 'treated': 1,...
# 592  {'groupon': 10, 'fail': 3, 'new': 15, 'york': ...
# 593  {'blistering': 1, 'hot': 1, 'day': 1, 'looking...
# 594  {'copied': 1, 'quizno': 1, 'come': 1, 'potbell...
# 595  {'local': 1, 'businesses': 1, 'like': 1, 'scou...
# 596  {'ick': 2, 'panini': 1, 'used': 1, 'caramel': ...
# 597  {'reason': 2, 'go': 3, 'close': 2, 'asu': 4, '...
# 598  {'love': 1, 'taco': 1, 'bell': 1, 'known': 1, ...
# 599  {'went': 2, 'day': 4, 'lunch': 3, 'disappointi...
# 600  {'native': 1, 'californian': 1, 'mexican': 1, ...
# 601  {'numerous': 1, 'times': 5, 'past': 5, 'seems'...
# 602  {'see': 1, 'much': 1, 'room': 2, 'improvement'...
# 603  {'healthy': 1, 'perhaps': 1, 'flavor': 1, 'les...
# 604  {'went': 10, 'friday': 1, 'night': 3, 'family'...
# 605  {'eaten': 2, 'way': 10, 'better': 13, 'indian'...
# 16   {'best': 51, 'vegetarian': 85, 'resteraunt': 2...
# 17   {'wo': 1, 'find': 2, 'zuma': 23, 'mill': 19, '...
# 18   {'ordered': 9, 'takeout': 3, 'wo': 2, 'comment...
# 19   {'decently': 1, 'fast': 1, 'good': 19, 'flavor...
# 20   {'puns': 2, 'alone': 1, 'enough': 10, 'two': 9...
# 21   {'stumbled': 1, 'across': 1, 'restaurant': 3, ...
# 22   {'love': 37, 'place': 88, 'everything': 8, 'al...
# 23   {'lunch': 16, 'dinner': 29, 'buffet': 93, 'foo...
# 24   {'denny': 9, 'forever': 1, 'good': 4, 'reason'...
# 25   {'fast': 3, 'food': 6, 'review': 1, 'based': 1...
# 26   {'jordin': 1, 'attentive': 2, 'friendly': 3, '...
# 27   {'typical': 1, 'burger': 1, 'king': 1, 'fast':...
# 28   {'tacos': 23, 'good': 16, 'barbacoa': 5, 'carn...
# 29   {'used': 1, 'big': 1, 'fan': 2, 'bagels': 2, '...
# ..                                                 ...
# 584  {'mcdonald': 1, 'twice': 1, 'service': 1, 'fas...
# 585  {'new': 4, 'hip': 1, 'sheek': 1, 'casual': 2, ...
# 586  {'dating': 1, 'back': 273, 'hundreds': 5, 'yea...
# 587  {'exceptional': 1, 'value': 2, 'great': 14, 'i...
# 588  {'always': 20, 'amazing': 7, 'experiences': 1,...
# 589                                                NaN
# 590  {'enjoy': 1, 'coming': 1, 'peter': 3, 'piper':...
# 591                                                NaN
# 592  {'first': 6, 'time': 10, 'today': 4, 'selectio...
# 593  {'came': 3, 'workout': 3, 'sun': 2, 'devil': 2...
# 594  {'partial': 1, 'potbelly': 16, 'first': 4, 'me...
# 595  {'great': 10, 'pool': 22, 'hall': 3, 'catch': ...
# 596  {'service': 1, 'breakfast': 1, 'always': 2, 'g...
# 597  {'place': 6, 'trying': 1, 'hippie': 1, 'hipste...
# 598  {'fast': 2, 'food': 8, 'quality': 2, 'service'...
# 599  {'family': 10, 'coming': 10, 'years': 10, 'fac...
# 600  {'love': 5, 'place': 5, 'mean': 1, 'lots': 1, ...
# 601  {'love': 63, 'place': 112, 'customize': 3, 'bo...
# 602  {'bad': 2, 'pizza': 1, 'ordered': 1, 'gambino'...
# 603  {'guys': 2, 'whenever': 1, 'mill': 4, 'absolut...
# 604  {'love': 9, 'ordering': 5, 'car': 1, 'side': 9...
# 605  {'tikka': 61, 'masala': 62, 'die': 7, 'love': ...
# 606  {'love': 5, 'barro': 12, 'pizza': 79, 'deliver...
# 607                                                NaN
# 608  {'food': 66, 'taste': 3, 'like': 16, 'pei': 1,...
# 609  {'first': 12, 'time': 46, 'restaurant': 23, 'c...
# 610  {'visit': 2, 'today': 3, 'carne': 22, 'asada':...
# 611  {'first': 23, 'timers': 3, 'charming': 6, 'pla...
# 612  {'hardee': 3, 'biscuits': 6, 'according': 1, '...
# 613  {'make': 9, 'mistake': 2, 'fine': 1, 'dining':...
#
#                                                  hours   latitude    ...      \
# 0    {'Monday': '10:00-0:00', 'Tuesday': '10:00-0:0...  33.414346    ...
# 1    {'Monday': '10:00-22:00', 'Tuesday': '10:00-22...  33.393322    ...
# 2    {'Monday': '17:00-22:00', 'Tuesday': '17:00-22...  33.406601    ...
# 3    {'Monday': '10:30-22:00', 'Tuesday': '10:30-22...  33.349310    ...
# 4    {'Monday': '6:00-0:00', 'Tuesday': '6:00-0:00'...  33.408298    ...
# 5    {'Monday': '11:00-2:00', 'Tuesday': '11:00-2:0...  33.423812    ...
# 6    {'Monday': '6:00-21:00', 'Tuesday': '6:00-21:0...  33.392400    ...
# 7    {'Monday': '17:00-21:30', 'Tuesday': '17:00-22...  33.377403    ...
# 8    {'Monday': '9:00-22:00', 'Tuesday': '11:00-22:...  33.425965    ...
# 9    {'Monday': '7:00-22:00', 'Tuesday': '7:00-22:0...  33.349062    ...
# 10   {'Monday': '7:00-19:00', 'Tuesday': '7:00-19:0...  33.421806    ...
# 11   {'Monday': '9:00-21:00', 'Tuesday': '9:00-21:0...  33.422113    ...
# 12                                                  {}  33.371409    ...
# 13                                                  {}  33.407717    ...
# 14   {'Monday': '11:00-21:00', 'Tuesday': '11:00-21...  33.349640    ...
# 15   {'Monday': '11:00-22:00', 'Tuesday': '11:00-22...  33.383147    ...
# 16   {'Monday': '11:00-21:00', 'Tuesday': '11:00-21...  33.421336    ...
# 17   {'Monday': '11:00-2:00', 'Tuesday': '11:00-2:0...  33.424106    ...
# 18   {'Monday': '11:00-21:30', 'Tuesday': '11:00-21...  33.363223    ...
# 19   {'Monday': '10:30-20:00', 'Tuesday': '10:30-20...  33.422894    ...
# 20   {'Monday': '10:00-0:00', 'Tuesday': '10:00-0:0...  33.422728    ...
# 21                                                  {}  33.407811    ...
# 22   {'Monday': '11:00-23:00', 'Tuesday': '11:00-23...  33.422307    ...
# 23   {'Monday': '17:00-23:00', 'Tuesday': '11:30-15...  33.416734    ...
# 24   {'Monday': '0:00-0:00', 'Tuesday': '0:00-0:00'...  33.384710    ...
# 25   {'Monday': '7:00-1:00', 'Tuesday': '7:00-1:00'...  33.393200    ...
# 26   {'Monday': '16:00-2:00', 'Tuesday': '16:00-0:0...  33.424127    ...
# 27                                                  {}  33.392455    ...
# 28   {'Monday': '11:00-22:00', 'Tuesday': '11:00-22...  33.377190    ...
# 29   {'Monday': '7:00-15:00', 'Tuesday': '7:00-15:0...  33.415273    ...
# ..                                                 ...        ...    ...
# 584                                                 {}  33.347468    ...
# 585  {'Monday': '11:00-21:00', 'Tuesday': '11:00-21...  33.362493    ...
# 586  {'Monday': '11:00-0:00', 'Tuesday': '11:00-0:0...  33.423059    ...
# 587  {'Monday': '10:00-2:00', 'Tuesday': '10:00-2:0...  33.415243    ...
# 588  {'Monday': '15:30-21:30', 'Tuesday': '15:30-21...  33.338336    ...
# 589  {'Monday': '8:00-22:00', 'Tuesday': '8:00-22:0...  33.377277    ...
# 590  {'Monday': '11:00-22:00', 'Tuesday': '11:00-22...  33.377364    ...
# 591  {'Monday': '7:00-22:00', 'Tuesday': '7:00-22:0...  33.406253    ...
# 592  {'Monday': '7:00-16:00', 'Tuesday': '7:00-16:0...  33.349713    ...
# 12    0.000000   0.000000   0.000000  50.000000
# 13   16.666667   9.523810  19.047619  35.714286
# 14    6.722689   7.563025  41.176471  38.655462
# 15   17.647059   5.882353  17.647059  29.411765
# 16    2.816901  11.971831  45.422535  37.676056
# 17   13.235294  23.529412  20.588235   7.352941
# 18   19.565217   7.608696  23.913043  17.391304
# 19    9.433962  26.415094  30.188679  22.641509
# 20   10.358566  15.139442  37.051793  31.872510
# 21   50.000000   0.000000  50.000000   0.000000
# 22   13.235294  19.607843  34.803922  20.588235
# 23    8.620690  13.793103  27.586207  37.931034
# 24    4.000000   8.000000  24.000000  20.000000
# 25   12.500000   0.000000   0.000000  75.000000
# 26   16.666667  11.111111  16.666667  29.629630
# 27   16.666667  25.000000   8.333333   0.000000
# 28   18.181818  11.363636  18.181818  27.272727
# 29   50.000000   0.000000   0.000000  50.000000
# ..         ...        ...        ...        ...
# 584   0.000000  14.285714   0.000000  14.285714
# 585  20.430108  12.903226  34.408602  22.580645
# 586   4.536862   8.317580  32.892250  52.646503
# 587   3.846154   3.846154  34.615385  57.692308
# 588  10.526316  11.842105  15.789474  42.105263
# 589   0.000000   0.000000   0.000000   0.000000
# 590  15.384615  15.384615  30.769231  15.384615
# 591   0.000000   0.000000   0.000000   0.000000
# 592  12.068966  20.689655  18.965517  31.034483
# 593  16.000000  16.000000  28.000000  36.000000
# 594   3.846154  19.230769  26.923077  44.230769
# 595   0.000000   5.882353  23.529412  64.705882
# 596  25.000000  12.500000  12.500000   0.000000
# 597  16.129032  32.258065  22.580645  12.903226
# 598  11.111111  22.222222  33.333333  33.333333
# 599  12.500000  18.055556  29.166667  33.333333
# 600  25.000000  25.000000  25.000000  25.000000
# 601  10.087719  21.052632  32.456140  27.192982
# 602   0.000000  25.000000  50.000000   0.000000
# 603   6.250000  18.750000  25.000000  31.250000
# 604  11.538462  12.820513  32.051282  25.641026
# 605   4.573171  17.378049  31.097561  41.768293
# 606   9.756098   7.317073  29.268293  41.463415
# 607   0.000000  50.000000   0.000000   0.000000
# 608   9.448819  16.535433  30.708661  33.070866
# 609  14.516129  19.892473  27.956989  20.967742
# 610   8.333333   9.375000  43.750000  37.500000
# 611  10.280374  11.214953  33.177570  36.448598
# 612  28.571429  21.428571  28.571429   7.142857
# 613   4.761905   8.571429  39.047619  37.142857
#
# [614 rows x 24 columns]

# %%
a = pd.concat([test, testBad])

# %%
goodText[0] = goodText[0].apply(orderDict)

# %%
a = odict(sorted(goodText[0][0].items(), key=lambda t: t[1], reverse=True))

# %%
test = {}
i = 0
for key, value in a.items():
    if i > 19:
        break
    test[key] = value
    i += 1

# %%
goodText[0][10]
# Out:
# {'asada': 5,
#  'breakfast': 8,
#  'burrito': 12,
#  'burritos': 5,
#  'carne': 5,
#  'cheese': 4,
#  'chorizo': 4,
#  'food': 9,
#  'fresh': 8,
#  'friendly': 5,
#  'go': 7,
#  'good': 5,
#  'great': 8,
#  'green': 6,
#  'hot': 6,
#  'made': 4,
#  'one': 9,
#  'options': 4,
#  'place': 10,
#  'try': 5}
